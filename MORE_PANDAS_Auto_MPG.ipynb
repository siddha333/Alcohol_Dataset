# %% [markdown]
# <a href="https://colab.research.google.com/github/siddha333/Alcohol_Dataset/blob/main/MORE_PANDAS_Auto_MPG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %%
url1 =  'https://raw.githubusercontent.com/a-forty-two/COG_GN22CDBDS001_MARCH_22/main/cars1.csv'
url2 =  'https://raw.githubusercontent.com/a-forty-two/COG_GN22CDBDS001_MARCH_22/main/cars2.csv'

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %%
cars1 = pd.read_csv(url1)
cars2 = pd.read_csv(url2)
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# ...

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cols = [9,10,11,12,13] 
cars1.drop(cars1.columns[cols], axis=1, inplace=True)
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
cars1.count()
# Out:
# mpg             198
# cylinders       198
# displacement    198
# horsepower      198
# weight          198
# acceleration    198
# model           198
# origin          198
# car             198
# dtype: int64

# %%
cars2.count()
# Out:
# mpg             200
# cylinders       200
# displacement    200
# horsepower      200
# weight          200
# acceleration    200
# model           200
# origin          200
# car             200
# dtype: int64

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars = pd.concat([cars1,cars2])
len(cars)
# Out:
# 398

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
arr = np.random.randint(low=15000,high=73000,size=398)
arr
# Out:
# array([25263, 33164, 47306, 63443, 28287, 23074, 69413, 52440, 54708,
#        70852, 45672, 65280, 21895, 33805, 56305, 66489, 30423, 42242,
#        19693, 41027, 50722, 17693, 63986, 69787, 40777, 37211, 42940,
#        46665, 45317, 66847, 59824, 50776, 71076, 54199, 32265, 71803,
#        68890, 64294, 71408, 70604, 63966, 65221, 51188, 22902, 40801,
#        53900, 49495, 35988, 16439, 18990, 36444, 37259, 48453, 20329,
#        66244, 38358, 44317, 39750, 63712, 23909, 70917, 61416, 58769,
#        36093, 60037, 40874, 61379, 52936, 52401, 19883, 61967, 58426,
#        52616, 49577, 49484, 68505, 35043, 34915, 15570, 68181, 65631,
#        66045, 30530, 15010, 44240, 22069, 54311, 47503, 16129, 38985,
#        58737, 40667, 25372, 67263, 30903, 65148, 46804, 71987, 71664,
#        19615, 40402, 30571, 17582, 34138, 17576, 55874, 20731, 15807,
#        71421, 38320, 58323, 61106, 19950, 53972, 22601, 34091, 67178,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owners'] = arr
cars.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
# 5  15.0          8           429        198    4341          10.0     70
# 6  14.0          8           454        220    4354           9.0     70
# 7  14.0          8           440        215    4312           8.5     70
# 8  14.0          8           455        225    4425          10.0     70
# 9  15.0          8           390        190    3850           8.5     70
#
#    origin                        car  owners
# 0       1  chevrolet chevelle malibu   25263
# 1       1          buick skylark 320   33164
# ...
